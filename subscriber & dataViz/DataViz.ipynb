# %%
import sqlite3
import folium
from folium import plugins
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dbName="PeopleTracking.db"
conn=sqlite3.connect(dbName)
curs=conn.cursor()
sql="""SELECT * FROM movementData"""
curs.execute(sql)
rslt=curs.fetchall()

# %%
data=dict()
data["id"]=list()
data["latitude"]=list()
data["longitude"]=list()
data["time"]=list()
data["speed"]=list()
data["id_device"]=list()
for row in rslt:
    data["id"].append(row[0])
    data["latitude"].append(float(row[1]))
    data["longitude"].append(float(row[2]))
    data["time"].append(row[3])
    data["speed"].append(float(row[4]))
    data["id_device"].append(row[5])

df=pd.DataFrame(data)

# %%
m = folium.Map([33.32, -7.35])
for index, row in df.iterrows():
    folium.CircleMarker([row['latitude'], row['longitude']],
                        radius=15,
                        popup=row['id'],
                        fill_color="#3db7e4", # divvy color
                       ).add_to(m)

# %%
# convert to (n, 2) nd-array format for heatmap
stationArr = df[['latitude', 'longitude']].as_matrix()

# plot heatmap
m.add_children(plugins.HeatMap(stationArr, radius=15))
m
# Out:
# c:\users\lenovo\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\lenovo\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
